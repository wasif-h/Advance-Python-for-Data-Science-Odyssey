# %% [markdown]
# <!-- Pandas  -->

# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %%
# series - one dimenstion array object

data = [1,2,3,4]

series = pd.Series(data)
print(series)
type(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# pandas.core.series.Series

# %%
# create a series from dictionary

data = {
    'a':1,
    'b':2,
    'c':3,
    'd':4
}

series = pd.Series(data)
print(series)
print(type(series))
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
data = [10,20,30]
new_index = ['a','b','c']

pd.Series(data,index = new_index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# DataFrame - 2d
# create a dataframe from dictionary

data = {
    # colname     values
    'Name' : ['Wasif','Hossain','Jhony'],
    'Age' : [23,18,15],
    'City' : ['New york','Uttara','Sydney']
}

df = pd.DataFrame(data)
display(df)
print(type(df))
# Out:
#       Name  Age      City
# 0    Wasif   23  New york
# 1  Hossain   18    Uttara
# 2    Jhony   15    Sydney
# <class 'pandas.core.frame.DataFrame'>

# %%
# convert the df into array

np.array(df)
# Out:
# array([['Wasif', 23, 'New york'],
#        ['Hossain', 18, 'Uttara'],
#        ['Jhony', 15, 'Sydney']], dtype=object)

# %%
# create df form list of dict

data = [
    {"Name": "Wasif", "Age": 23, "City": "Dhaka"},
    {"Name": "Sunny", "Age": 23, "City": "Dhaka"},
    {"Name": "Rejoan", "Age": 23, "City": "Dhaka"},
    {"Name": "Hasan", "Age": 23, "City": "Dhaka"},
    {"Name": "Galib", "Age": 23, "City": "Dhaka"}
]

df = pd.DataFrame(data)
display(df)
print(type(df))
# Out:
#      Name  Age   City
# 0   Wasif   23  Dhaka
# 1   Sunny   23  Dhaka
# 2  Rejoan   23  Dhaka
# 3   Hasan   23  Dhaka
# 4   Galib   23  Dhaka
# <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# we can directly access column like this

# df['embark_town'] and it will become series
df['embark_town'].head()
# Out:
# 0    Southampton
# 1      Cherbourg
# 2    Southampton
# 3    Southampton
# 4    Southampton
# Name: embark_town, dtype: object

# %%
data = [
    {"Name": "John", "Age": 22, "City": "Dhaka"},
    {"Name": "Jack", "Age": 24, "City": "Chattogram"},
    {"Name": "Emily", "Age": 21, "City": "Sylhet"},
    {"Name": "Sophia", "Age": 23, "City": "Rajshahi"},
    {"Name": "Michael", "Age": 25, "City": "Khulna"}
]
df = pd.DataFrame(data)
df
# Out:
#       Name  Age        City
# 0     John   22       Dhaka
# 1     Jack   24  Chattogram
# 2    Emily   21      Sylhet
# 3   Sophia   23    Rajshahi
# 4  Michael   25      Khulna

# %%
df.loc[0]["Name"]
# Out:
# 'John'

# %%
df.iloc[2]
# Out:
# Name     Emily
# Age         21
# City    Sylhet
# Name: 2, dtype: object

# %%
df.iloc[2][1]
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4172\2023769522.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[2][1]
# np.int64(21)

# %%
# adding a column 

df['Salary'] = [2,3,4,5,6]
df
# Out:
#       Name  Age        City  Salary
# 0     John   22       Dhaka       2
# 1     Jack   24  Chattogram       3
# 2    Emily   21      Sylhet       4
# 3   Sophia   23    Rajshahi       5
# 4  Michael   25      Khulna       6

# %%
# two ways to make it permanent drop
# df = df.drop('Salary', axis=1)
# df.drop('Salary', axis=1 , inplace=True)
# x axis or row axis = 0
# y axis or col axis = 1
df.drop('Salary', axis=1)
# Out:
#       Name  Age        City
# 0     John   22       Dhaka
# 1     Jack   24  Chattogram
# 2    Emily   21      Sylhet
# 3   Sophia   23    Rajshahi
# 4  Michael   25      Khulna

# %%
df
# Out:
#       Name  Age        City  Salary
# 0     John   22       Dhaka       2
# 1     Jack   24  Chattogram       3
# 2    Emily   21      Sylhet       4
# 3   Sophia   23    Rajshahi       5
# 4  Michael   25      Khulna       6

# %%
df.drop('Salary', axis=1, inplace=True)

# %%
df
# Out:
#       Name  Age        City
# 0     John   22       Dhaka
# 1     Jack   24  Chattogram
# 2    Emily   21      Sylhet
# 3   Sophia   23    Rajshahi
# 4  Michael   25      Khulna

# %%
df["Age"] = df["Age"] + 1 # each of them
df
# Out:
#       Name  Age        City
# 0     John   23       Dhaka
# 1     Jack   25  Chattogram
# 2    Emily   22      Sylhet
# 3   Sophia   24    Rajshahi
# 4  Michael   26      Khulna

# %%
# stastistical analysis or five number summary 

df.describe()
# Out:
#              Age
# count   5.000000
# mean   24.000000
# std     1.581139
# min    22.000000
# 25%    23.000000
# 50%    24.000000
# 75%    25.000000
# max    26.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes

# %% [markdown]
# ### Data Manipulation

# %%
data = pd.read_csv("data.csv")
display(data.sample(10))
print(data.info())
print(data.describe())
# Out:
#           Date Category  Value   Product  Sales Region
# 45  2023-02-15        B   99.0  Product2  599.0   West
# 16  2023-01-17        C   93.0  Product2  511.0  South
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 21  2023-01-22        C   37.0  Product2  992.0  South
# 41  2023-02-11        C   97.0  Product1  256.0   East
# 28  2023-01-29        B    NaN  Product3  617.0  North
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 20  2023-01-21        C   82.0  Product3  606.0  South
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 23  2023-01-24        C   92.0  Product2  342.0   West
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      50 non-null     object
#  1   Category  50 non-null     object
#  2   Value     47 non-null     float64
#  3   Product   50 non-null     object
# ...

# %%
# handling missing values 

data.isnull()
# Out:
#      Date  Category  Value  Product  Sales  Region
# 0   False     False  False    False  False   False
# 1   False     False  False    False  False   False
# 2   False     False  False    False  False   False
# 3   False     False  False    False  False   False
# 4   False     False  False    False  False   False
# 5   False     False  False    False  False   False
# 6   False     False  False    False  False   False
# 7   False     False  False    False  False   False
# 8   False     False  False    False  False   False
# 9   False     False  False    False  False   False
# 10  False     False  False    False  False   False
# 11  False     False  False    False   True   False
# 12  False     False  False    False  False   False
# 13  False     False  False    False  False   False
# 14  False     False  False    False  False   False
# 15  False     False   True    False  False   False
# 16  False     False  False    False  False   False
# ...

# %%
data.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
data2 = data.fillna(0)
data2.isnull().sum()
data2.sample(10)
# Out:
#           Date Category  Value   Product  Sales Region
# 16  2023-01-17        C   93.0  Product2  511.0  South
# 19  2023-01-20        A   59.0  Product1  736.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 23  2023-01-24        C   92.0  Product2  342.0   West
# 44  2023-02-14        A   96.0  Product3  830.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 20  2023-01-21        C   82.0  Product3  606.0  South
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 33  2023-02-03        C   27.0  Product3    0.0   East

# %%
# filling the null using mean 

data["Sales_Filled"] = data["Sales"].fillna(data['Sales'].mean())
data.head(20)
# Out:
#           Date Category  Value   Product  Sales Region  Sales_Filled
# 0   2023-01-01        A   28.0  Product1  754.0   East    754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North    110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East    398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East    522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North    869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West    192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East    936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West    488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West    772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West    834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North    842.000000
# 11  2023-01-12        B   60.0  Product2    NaN   West    557.130435
# 12  2023-01-13        A   70.0  Product3  628.0  South    628.000000
# ...

# %%
data.dtypes
# Out:
# Date             object
# Category         object
# Value           float64
# Product          object
# Sales           float64
# Region           object
# Sales_Filled    float64
# dtype: object

# %%
## renaming column

data.rename(columns={'Date': "Sale_Data"})
# Out:
#      Sale_Data Category  Value   Product  Sales Region  Sales_Filled
# 0   2023-01-01        A   28.0  Product1  754.0   East    754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North    110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East    398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East    522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North    869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West    192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East    936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West    488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West    772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West    834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North    842.000000
# 11  2023-01-12        B   60.0  Product2    NaN   West    557.130435
# 12  2023-01-13        A   70.0  Product3  628.0  South    628.000000
# ...

# %%
## change data type

data["Sales_Filled_int"] = data["Sales_Filled"].astype(int)

# %%
data
# Out:
#           Date Category  Value   Product  Sales Region  Sales_Filled  \
# 0   2023-01-01        A   28.0  Product1  754.0   East    754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North    110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East    398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East    522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North    869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West    192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East    936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West    488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West    772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West    834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North    842.000000
# 11  2023-01-12        B   60.0  Product2    NaN   West    557.130435
# 12  2023-01-13        A   70.0  Product3  628.0  South    628.000000
# ...

# %%
# handle missing values

data['Value'] = data["Value"].fillna(data["Value"].mean()).astype(int)

# %%
data.head()
# Out:
#          Date Category  Value   Product  Sales Region  Sales_Filled  \
# 0  2023-01-01        A     28  Product1  754.0   East         754.0
# 1  2023-01-02        B     39  Product3  110.0  North         110.0
# 2  2023-01-03        C     32  Product2  398.0   East         398.0
# 3  2023-01-04        B      8  Product1  522.0   East         522.0
# 4  2023-01-05        B     26  Product3  869.0  North         869.0
#
#    Sales_Filled_int
# 0               754
# 1               110
# 2               398
# 3               522
# 4               869

# %%
# how to apply function any column
# suppose I want to double the value in a new col

def double(item):
    return item * 2


data["Value_2x"] = data["Value"].apply(double)
# or data["Value_2x"] = data["Value"].apply(lambda x: x * 2) 
data.head()
# Out:
#          Date Category  Value   Product  Sales Region  Sales_Filled  \
# 0  2023-01-01        A     28  Product1  754.0   East         754.0
# 1  2023-01-02        B     39  Product3  110.0  North         110.0
# 2  2023-01-03        C     32  Product2  398.0   East         398.0
# 3  2023-01-04        B      8  Product1  522.0   East         522.0
# 4  2023-01-05        B     26  Product3  869.0  North         869.0
#
#    Sales_Filled_int  Value_2x
# 0               754        56
# 1               110        78
# 2               398        64
# 3               522        16
# 4               869        52

# %%
# Data aggregating and grouping

grp_mean = data.groupby('Product')['Value'].mean()
grp_mean
# Out:
# Product
# Product1    46.812500
# Product2    52.800000
# Product3    54.947368
# Name: Value, dtype: float64

# %%
# if i need to group by by two categorical parameter 

grp2 = data.groupby(['Product','Region'])["Value"].sum()
grp2
# Out:
# Product   Region
# Product1  East      292
#           North      60
#           South     100
#           West      297
# Product2  East       56
#           North     127
#           South     181
#           West      428
# Product3  East      202
#           North     254
#           South     215
#           West      373
# Name: Value, dtype: int64

# %%
grp2 = data.groupby(['Product','Region'])["Value"].mean()
grp2
# Out:
# Product   Region
# Product1  East      41.714286
#           North     20.000000
#           South     50.000000
#           West      74.250000
# Product2  East      28.000000
#           North     63.500000
#           South     60.333333
#           West      53.500000
# Product3  East      50.500000
#           North     42.333333
#           South     71.666667
#           West      62.166667
# Name: Value, dtype: float64

# %%
# multiple aggregate function 

grp2 = data.groupby('Region')["Value"].agg(['mean','sum','count'])
grp2
# Out:
#              mean   sum  count
# Region
# East    42.307692   550     13
# North   40.090909   441     11
# South   62.000000   496      8
# West    61.000000  1098     18

# %%
# merging and joining data frame

df1 = pd.DataFrame({'Key':["A",'B','C'],'Value1':[1,2,3]})
df2 = pd.DataFrame({'Key':["A",'B','D'],'Value1':[4,5,6]})

display(df1)
display(df2)
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3
#   Key  Value1
# 0   A       4
# 1   B       5
# 2   D       6

# %%
pd.merge(df1,df2,on="Key",how="inner")
# Out:
#   Key  Value1_x  Value1_y
# 0   A         1         4
# 1   B         2         5

# %%
pd.merge(df1,df2,on="Key",how="outer")
# Out:
#   Key  Value1_x  Value1_y
# 0   A       1.0       4.0
# 1   B       2.0       5.0
# 2   C       3.0       NaN
# 3   D       NaN       6.0

# %%
pd.merge(df1,df2,on="Key",how="left")
# Out:
#   Key  Value1_x  Value1_y
# 0   A         1       4.0
# 1   B         2       5.0
# 2   C         3       NaN

# %%
pd.merge(df1,df2,on="Key",how="right")
# Out:
#   Key  Value1_x  Value1_y
# 0   A       1.0         4
# 1   B       2.0         5
# 2   D       NaN         6

# %% [markdown]
# ### Read Data from Various Source

# %%
# https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data 
# online dataset link 

df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data")
df.to_csv("wine.csv")

# %%
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
# collecting data from Website 

# %pip install lxml
# %pip install html5lib
# %pip install beautifulsoup4
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.8 MB 2.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/3.8 MB 2.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.6/3.8 MB 2.0 MB/s eta 0:00:02
#    ------------------- -------------------- 1.8/3.8 MB 1.9 MB/s eta 0:00:02
#    --------------------- ------------------ 2.1/3.8 MB 1.8 MB/s eta 0:00:01
#    ------------------------ --------------- 2.4/3.8 MB 1.8 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 1.7 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.8 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 1.6 MB/s eta 0:00:00
# ...

# %%
# from html 
# www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list


url="https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/"


df = pd.read_html(url)
display(df)
# Out:
# [                               Bank Name               City         State  \
#  0                   Pulaski Savings Bank            Chicago      Illinois
#  1     The First National Bank of Lindsay            Lindsay      Oklahoma
#  2  Republic First Bank dba Republic Bank       Philadelphia  Pennsylvania
#  3                          Citizens Bank           Sac City          Iowa
#  4               Heartland Tri-State Bank            Elkhart        Kansas
#  5                    First Republic Bank      San Francisco    California
#  6                         Signature Bank           New York      New York
#  7                    Silicon Valley Bank        Santa Clara    California
#  8                      Almena State Bank             Almena        Kansas
#  9             First City Bank of Florida  Fort Walton Beach       Florida
#
#      Cert                Acquiring Institution      Closing Date  \
#  0  28611                      Millennium Bank  January 17, 2025
# ...

# %%
df[0]
# Out:
#                                Bank Name               City         State  \
# 0                   Pulaski Savings Bank            Chicago      Illinois
# 1     The First National Bank of Lindsay            Lindsay      Oklahoma
# 2  Republic First Bank dba Republic Bank       Philadelphia  Pennsylvania
# 3                          Citizens Bank           Sac City          Iowa
# 4               Heartland Tri-State Bank            Elkhart        Kansas
# 5                    First Republic Bank      San Francisco    California
# 6                         Signature Bank           New York      New York
# 7                    Silicon Valley Bank        Santa Clara    California
# 8                      Almena State Bank             Almena        Kansas
# 9             First City Bank of Florida  Fort Walton Beach       Florida
#
#     Cert                Acquiring Institution      Closing Date  \
# 0  28611                      Millennium Bank  January 17, 2025
# ...

# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"
df = pd.read_html(url,match="List of countries and territories by total population",header=0)
df[0]
# Out:
#                                 Location  Population % of world         Date  \
# 0                                  World  8138506850       100%  20 Apr 2025
# 1                                  India  1413324000      17.3%   1 Mar 2025
# 2                                  China  1408280000      17.2%  31 Dec 2024
# 3                          United States   340110988       4.2%   1 Jul 2024
# 4                              Indonesia   282477584       3.5%  30 Jun 2024
# ..                                   ...         ...        ...          ...
# 235                   Niue (New Zealand)        1681         0%  11 Nov 2022
# 236                Tokelau (New Zealand)        1647         0%   1 Jan 2019
# 237                         Vatican City         882         0%  31 Dec 2024
# 238  Cocos (Keeling) Islands (Australia)         593         0%  30 Jun 2020
# 239                Pitcairn Islands (UK)          35         0%   1 Jul 2023
#
# ...
